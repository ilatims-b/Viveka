# %%
# !pwd
# Out:
# /content

# %%
# %cd TruthFlow/
# Out:
# /content/TruthFlow

# %%
# !pip install condacolab
import condacolab
condacolab.install()
# Out:
# Collecting condacolab
#   Downloading condacolab-0.1.10-py3-none-any.whl.metadata (5.5 kB)
# Downloading condacolab-0.1.10-py3-none-any.whl (7.2 kB)
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.10
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !conda update -n base -c conda-forge conda
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.14  |       hbd8a1cb_0         152 KB  conda-forge
#     certifi-2025.7.14          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     openssl-3.5.1              |       h7b32b05_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.4 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.7.14-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.7.14-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.1-h7b32b05_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.5.1        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
# conda-24.11.3        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2025.7.14    | 156 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ca-certificates-2025 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00, 13.82it/s]
#
#
# openssl-3.5.1        | 3.0 MB    | :  26% 0.2616414809061125/1 [00:00<00:00,  2.61it/s]
# conda-24.11.3        | 1.1 MB    | :  67% 0.6685420112154264/1 [00:00<00:00,  6.65it/s]
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.65it/s]
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  7.74it/s]
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  7.74it/s]
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  7.57it/s]
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !conda create -n venvTruthFlow python=3.11.9
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/venvTruthFlow
#
#   added / updated specs:
#     - python=3.11.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.44      |       h1423503_1         660 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libgcc-15.1.0              |       h767d61c_4         805 KB  conda-forge
#     libgcc-ng-15.1.0           |       h69a702a_4          29 KB  conda-forge
#     libgomp-15.1.0             |       h767d61c_4         437 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     liblzma-devel-5.8.1        |       hb9d3cd8_2         430 KB  conda-forge
#     libnsl-2.0.1               |       hb9d3cd8_1          33 KB  conda-forge
#     libsqlite-3.50.4           |       h0c1763c_0         911 KB  conda-forge
#     ncurses-6.5                |       h2d0b736_3         871 KB  conda-forge
#     pip-25.2                   |     pyh8b19718_0         1.1 MB  conda-forge
#     python-3.11.9              |hb806964_0_cpython        29.5 MB  conda-forge
#     readline-8.2               |       h8c095d6_2         276 KB  conda-forge
#     setuptools-80.9.0          |     pyhff2d567_0         731 KB  conda-forge
#     tk-8.6.13                  |noxft_hd72426e_102         3.1 MB  conda-forge
#     tzdata-2025b               |       h78e105d_0         120 KB  conda-forge
#     xz-5.8.1                   |       hbcc6ac9_2          23 KB  conda-forge
#     xz-gpl-tools-5.8.1         |       hbcc6ac9_2          33 KB  conda-forge
#     xz-tools-5.8.1             |       hb9d3cd8_2          94 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        39.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/noarch::ca-certificates-2025.7.14-hbd8a1cb_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.44-h1423503_1
#   libexpat           conda-forge/linux-64::libexpat-2.7.1-hecca717_0
#   libffi             conda-forge/linux-64::libffi-3.4.6-h2dba641_1
#   libgcc             conda-forge/linux-64::libgcc-15.1.0-h767d61c_4
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-15.1.0-h69a702a_4
#   libgomp            conda-forge/linux-64::libgomp-15.1.0-h767d61c_4
#   liblzma            conda-forge/linux-64::liblzma-5.8.1-hb9d3cd8_2
#   liblzma-devel      conda-forge/linux-64::liblzma-devel-5.8.1-hb9d3cd8_2
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hb9d3cd8_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.50.4-h0c1763c_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   ncurses            conda-forge/linux-64::ncurses-6.5-h2d0b736_3
#   openssl            conda-forge/linux-64::openssl-3.5.1-h7b32b05_0
#   pip                conda-forge/noarch::pip-25.2-pyh8b19718_0
#   python             conda-forge/linux-64::python-3.11.9-hb806964_0_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8c095d6_2
#   setuptools         conda-forge/noarch::setuptools-80.9.0-pyhff2d567_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_hd72426e_102
#   tzdata             conda-forge/noarch::tzdata-2025b-h78e105d_0
#   wheel              conda-forge/noarch::wheel-0.45.1-pyhd8ed1ab_1
#   xz                 conda-forge/linux-64::xz-5.8.1-hbcc6ac9_2
#   xz-gpl-tools       conda-forge/linux-64::xz-gpl-tools-5.8.1-hbcc6ac9_2
#   xz-tools           conda-forge/linux-64::xz-tools-5.8.1-hb9d3cd8_2
#
#
#
# Downloading and Extracting Packages:
# python-3.11.9        | 29.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# pip-25.2             | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libsqlite-3.50.4     | 911 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ncurses-6.5          | 871 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgcc-15.1.0        | 805 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-gpl-tools-5.8.1   | 33 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# python-3.11.9        | 29.5 MB   | :  10% 0.1023850997850248/1 [00:00<00:01,  1.17s/it]
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00,  8.74it/s]
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00,  8.74it/s]
#
#
# libsqlite-3.50.4     | 911 KB    | :   2% 0.017568447137567673/1 [00:00<00:06,  7.06s/it]
#
# pip-25.2             | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.81it/s]
#
# pip-25.2             | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.81it/s]
#
#
#
#
# libgcc-15.1.0        | 805 KB    | :   2% 0.019879803871368545/1 [00:00<00:07,  7.67s/it]
#
#
# libsqlite-3.50.4     | 911 KB    | : 100% 1.0/1 [00:00<00:00,  7.06s/it]
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   2% 0.021880692532465797/1 [00:00<00:07,  8.17s/it]
#
#
#
#
# libgcc-15.1.0        | 805 KB    | : 100% 1.0/1 [00:00<00:00,  7.67s/it]
#
#
#
#
#
#
# python-3.11.9        | 29.5 MB   | :  22% 0.21856301094005295/1 [00:00<00:00,  1.06s/it]
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:00<00:00,  8.17s/it]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  8.76it/s]
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | :   4% 0.03662956164806199/1 [00:00<00:06,  6.70s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:00<00:00,  8.78s/it]
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | : 100% 1.0/1 [00:00<00:00,  6.70s/it]
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   6% 0.05800056641178136/1 [00:00<00:04,  4.82s/it]
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:00<00:00,  4.82s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :  13% 0.1332379155552664/1 [00:00<00:01,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :  15% 0.1451272875440679/1 [00:00<00:01,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:00<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   4% 0.037247537897732955/1 [00:00<00:08,  8.34s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:00<00:00,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :  17% 0.1699003453174743/1 [00:00<00:01,  1.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:00<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
# python-3.11.9        | 29.5 MB   | :  35% 0.34641176248508393/1 [00:00<00:00,  1.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-gpl-tools-5.8.1   | 33 KB     | :  48% 0.4831470614254961/1 [00:00<00:00,  1.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-gpl-tools-5.8.1   | 33 KB     | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | :  22% 0.2190052265041237/1 [00:00<00:01,  1.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | : 100% 1.0/1 [00:00<00:00,  1.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | :  49% 0.4857252972043521/1 [00:00<00:00,  1.30it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :  29% 0.2852715337871955/1 [00:00<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:00<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | :  56% 0.5601559027659065/1 [00:00<00:00,  1.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.9        | 29.5 MB   | :  75% 0.751177726920182/1 [00:00<00:00,  1.60it/s]
#
# pip-25.2             | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.81it/s]
#
#
# libsqlite-3.50.4     | 911 KB    | : 100% 1.0/1 [00:00<00:00,  1.04it/s]
#
#
# python-3.11.9        | 29.5 MB   | : 100% 1.0/1 [00:01<00:00,  1.36s/it]
#
#
#
#
# libgcc-15.1.0        | 805 KB    | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
#
#
#
#
# libgcc-15.1.0        | 805 KB    | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:01<00:00,  1.51s/it]
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:01<00:00,  1.51s/it]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:02<00:00,  8.76it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.11s/it]
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.11s/it]
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  8.74it/s]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-gpl-tools-5.8.1   | 33 KB     | : 100% 1.0/1 [00:02<00:00,  2.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-gpl-tools-5.8.1   | 33 KB     | : 100% 1.0/1 [00:02<00:00,  2.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | : 100% 1.0/1 [00:02<00:00,  2.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | : 100% 1.0/1 [00:02<00:00,  2.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | : 100% 1.0/1 [00:02<00:00,  2.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.9        | 29.5 MB   | : 100% 1.0/1 [00:03<00:00,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate venvTruthFlow
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
from huggingface_hub import login
login(new_session=False)

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# cd TruthFlow/
# conda activate venvTruthFlow
# # python --version
# # pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121
# # pip install -r requirements.txt
# # python create_ds.py --model_name gemma-2 --layers 18 20 22 --test_size 0.5 --seed 0 --token_pos ans_avg --ds_name tqa gemma-2_ans_avg_seed0_testsize0.5_layers_18_20_22
# python flow.py --model_name gemma-2 --ds_path data_tqa/gemma-2_ans_avg_seed0_testsize0.5_layers_18_20_22 --layers 20 --seed 0 --truthflow --mc_eval --k 20 --alpha 1.5 --train --num_epochs 40
# conda deactivate
# Out:
# Loading google/gemma-2-2b...
# Loading checkpoint shards: 100% 3/3 [00:57<00:00, 19.07s/it]
# Start training...
# Epoch [1/40] - Training: 100% 3/3 [00:00<00:00,  3.24it/s, train_loss=17.7]
# Epoch [2/40] - Training: 100% 3/3 [00:00<00:00, 27.89it/s, train_loss=17.6]
# Epoch [3/40] - Training: 100% 3/3 [00:00<00:00, 27.62it/s, train_loss=17.3]
# Epoch [4/40] - Training: 100% 3/3 [00:00<00:00, 31.23it/s, train_loss=17.3]
# Epoch [5/40] - Training: 100% 3/3 [00:00<00:00, 32.67it/s, train_loss=17]
# Epoch [6/40] - Training: 100% 3/3 [00:00<00:00, 32.41it/s, train_loss=16.6]
# Epoch [7/40] - Training: 100% 3/3 [00:00<00:00, 31.18it/s, train_loss=16.2]
# Epoch [8/40] - Training: 100% 3/3 [00:00<00:00, 33.10it/s, train_loss=15.8]
# Epoch [9/40] - Training: 100% 3/3 [00:00<00:00, 33.49it/s, train_loss=15.6]
# Epoch [10/40] - Training: 100% 3/3 [00:00<00:00, 33.70it/s, train_loss=14.6]
# Epoch [11/40] - Training: 100% 3/3 [00:00<00:00, 32.72it/s, train_loss=14.4]
# Epoch [12/40] - Training: 100% 3/3 [00:00<00:00, 33.58it/s, train_loss=14]
# Epoch [13/40] - Training: 100% 3/3 [00:00<00:00, 33.76it/s, train_loss=13.1]
# Epoch [14/40] - Training: 100% 3/3 [00:00<00:00, 30.45it/s, train_loss=12.4]
# Epoch [15/40] - Training: 100% 3/3 [00:00<00:00, 33.03it/s, train_loss=11.8]
# Epoch [16/40] - Training: 100% 3/3 [00:00<00:00, 32.32it/s, train_loss=11]
# Epoch [17/40] - Training: 100% 3/3 [00:00<00:00, 32.11it/s, train_loss=10.2]
# Epoch [18/40] - Training: 100% 3/3 [00:00<00:00, 32.06it/s, train_loss=9.62]
# Epoch [19/40] - Training: 100% 3/3 [00:00<00:00, 33.42it/s, train_loss=9.11]
# Epoch [20/40] - Training: 100% 3/3 [00:00<00:00, 32.40it/s, train_loss=8.59]
# Epoch [21/40] - Training: 100% 3/3 [00:00<00:00, 32.79it/s, train_loss=8.32]
# Epoch [22/40] - Training: 100% 3/3 [00:00<00:00, 33.63it/s, train_loss=7.54]
# Epoch [23/40] - Training: 100% 3/3 [00:00<00:00, 32.84it/s, train_loss=7.3]
# Epoch [24/40] - Training: 100% 3/3 [00:00<00:00, 32.63it/s, train_loss=7.03]
# Epoch [25/40] - Training: 100% 3/3 [00:00<00:00, 29.10it/s, train_loss=6.72]
# Epoch [26/40] - Training: 100% 3/3 [00:00<00:00, 32.52it/s, train_loss=6.29]
# Epoch [27/40] - Training: 100% 3/3 [00:00<00:00, 33.14it/s, train_loss=6.1]
# Epoch [28/40] - Training: 100% 3/3 [00:00<00:00, 32.45it/s, train_loss=5.99]
# Epoch [29/40] - Training: 100% 3/3 [00:00<00:00, 31.45it/s, train_loss=5.85]
# Epoch [30/40] - Training: 100% 3/3 [00:00<00:00, 33.97it/s, train_loss=5.53]
# Epoch [31/40] - Training: 100% 3/3 [00:00<00:00, 33.55it/s, train_loss=5.12]
# Epoch [32/40] - Training: 100% 3/3 [00:00<00:00, 33.07it/s, train_loss=5.05]
# Epoch [33/40] - Training: 100% 3/3 [00:00<00:00, 34.14it/s, train_loss=4.96]
# Epoch [34/40] - Training: 100% 3/3 [00:00<00:00, 33.78it/s, train_loss=4.77]
# Epoch [35/40] - Training: 100% 3/3 [00:00<00:00, 34.17it/s, train_loss=4.71]
# Epoch [36/40] - Training: 100% 3/3 [00:00<00:00, 32.41it/s, train_loss=4.74]
# Epoch [37/40] - Training: 100% 3/3 [00:00<00:00, 24.16it/s, train_loss=4.48]
# Epoch [38/40] - Training: 100% 3/3 [00:00<00:00, 23.36it/s, train_loss=4.4]
# Epoch [39/40] - Training: 100% 3/3 [00:00<00:00, 25.00it/s, train_loss=4.44]
# Epoch [40/40] - Training: 100% 3/3 [00:00<00:00, 26.51it/s, train_loss=4.19]
# Training time: 4.68293309211731
# 100% 409/409 [04:46<00:00,  1.43it/s]
# MC1: 0.31295843520782396, MC2: 0.5052449032689365
